# %% [markdown]
# # Projeto 2 - Como pegar dados em sites e automatizar a criação da carteira

# %% [markdown]
# ## Passo a passo
#
#  - 1 - definir o navegador
#  - 2 - importar os módulos e bibliotecas
#  - 3 - entender como funcionam requisições na internet
#  - 4 - entender como sites funcionam
#  - 5 - conhecer e mapear o processo de coleta de dados no site Fundamentus
#  - 6 - ler a tabela de dados
#  - 7 - construir a tabela final

# %% [markdown]
# ### 1 - definir o navegador
#
# neste caso, utilizarei o Google Chrome

# %% [markdown]
# ### 2 - importar os módulos e bibliotecas

# %%
# !pip install selenium

# %%
# !pip install webdriver-manager

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %% [markdown]
# ### 3 - entender como funcionam requisições na internet

# %%
# driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()))
driver = webdriver.Chrome('../chromedriver.exe')

url = 'https://www.fundamentus.com.br/resultado.php'

driver.get(url)
# Out:
# C:\Users\bruno.dorea.SPREADTEC\AppData\Local\Temp\ipykernel_13004\1247649361.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('../chromedriver.exe')

# %% [markdown]
# ### 4 - entender como sites funcionam

# %% [markdown]
# ### 5 - conhecer e mapear o processo de coleta de dados no site Fundamentus

# %% [markdown]
# ### 6 - ler a tabela de dados

# %%
local_tabela = '/html/body/div[1]/div[2]/table'

elemento = driver.find_element("xpath", local_tabela)

html_tabela = elemento.get_attribute('outerHTML')

tabela = pd.read_html(str(html_tabela), thousands = '.', decimal = ',')[0]

tabela
# Out:
#       Papel  Cotação      P/L   P/VP    PSR Div.Yield  P/Ativo  P/Cap.Giro  \
# 0     CSTB4   147.69     0.00   0.00  0.000     0,00%    0.000        0.00
# 1     MNSA4     0.47     0.00   0.00  0.000     0,00%    0.000        0.00
# 2     PORP4     2.40     0.00   0.00  0.000     0,00%    0.000        0.00
# 3     POPR4    10.17     0.00   0.00  0.000     0,00%    0.000        0.00
# 4     IVTT3     0.00     0.00   0.00  0.000     0,00%    0.000        0.00
# ..      ...      ...      ...    ...    ...       ...      ...         ...
# 982   PRBC4    14.54   502.29  40.26  0.000     0,00%    0.000        0.00
# 983   UBBR4     7.49   610.27   1.99  0.000     0,00%    0.000        0.00
# 984  UBBR11    14.75  1201.81   3.91  0.000     0,00%    0.000        0.00
# 985   UBBR3    18.00  1466.61   4.77  0.000     0,00%    0.000        0.00
# 986   SQIA3    26.65  2672.35   3.66  3.569     0,21%    1.461       26.34
#
# ...

# %% [markdown]
# ### 7 - construir a tabela final

# %%
tabela = tabela.set_index("Papel")
tabela = tabela[['Cotação', 'EV/EBIT', 'ROIC', 'Liq.2meses']]

tabela
# Out:
#         Cotação  EV/EBIT     ROIC  Liq.2meses
# Papel
# CSTB4    147.69      0.0   22,40%         0.0
# MNSA4      0.47      0.0  -13,50%         0.0
# PORP4      2.40      0.0    0,00%         0.0
# POPR4     10.17      0.0   15,25%         0.0
# IVTT3      0.00      0.0    0,00%         0.0
# ...         ...      ...      ...         ...
# PRBC4     14.54      0.0    0,00%         0.0
# UBBR4      7.49      0.0    0,00%         0.0
# UBBR11    14.75      0.0    0,00%         0.0
# UBBR3     18.00      0.0    0,00%         0.0
# SQIA3     26.65     45.9    4,04%  25416100.0
#
# [987 rows x 4 columns]

# %%
# transformar texto em numero

tabela['ROIC'] = tabela['ROIC'].str.replace('%', '')
tabela['ROIC'] = tabela['ROIC'].str.replace('.', '')
tabela['ROIC'] = tabela['ROIC'].str.replace(',', '.')
tabela['ROIC'] = tabela['ROIC'].astype(float)

tabela
# Out:
#         Cotação  EV/EBIT   ROIC  Liq.2meses
# Papel
# CSTB4    147.69      0.0  22.40         0.0
# MNSA4      0.47      0.0 -13.50         0.0
# PORP4      2.40      0.0   0.00         0.0
# POPR4     10.17      0.0  15.25         0.0
# IVTT3      0.00      0.0   0.00         0.0
# ...         ...      ...    ...         ...
# PRBC4     14.54      0.0   0.00         0.0
# UBBR4      7.49      0.0   0.00         0.0
# UBBR11    14.75      0.0   0.00         0.0
# UBBR3     18.00      0.0   0.00         0.0
# SQIA3     26.65     45.9   4.04  25416100.0
#
# [987 rows x 4 columns]

# %%
# criando filtros e os rankings

tabela = tabela[tabela['Liq.2meses'] > 1000000]

tabela
# Out:
#        Cotação  EV/EBIT   ROIC   Liq.2meses
# Papel
# QUAL3     3.90     5.21  13.95   20118000.0
# MEGA3    10.65    25.10   3.66    8310680.0
# LWSA3     6.54    43.11   2.03   51831100.0
# CBAV3     4.28    87.16   0.53   35498100.0
# MYPK3    14.76     9.12   6.73   21019000.0
# ...        ...      ...    ...          ...
# CRFB3    11.26     8.72   6.66  121111000.0
# YDUQ3    22.25    14.88   8.99  116395000.0
# CEAB3     6.17     7.69   5.28   26425400.0
# PTBL3     6.99    11.27   7.36   10911000.0
# SQIA3    26.65    45.90   4.04   25416100.0
#
# [244 rows x 4 columns]

# %%
tabela = tabela[tabela['EV/EBIT'] > 0]
tabela = tabela[tabela['ROIC'] > 0]

tabela
# Out:
#        Cotação  EV/EBIT   ROIC   Liq.2meses
# Papel
# QUAL3     3.90     5.21  13.95   20118000.0
# MEGA3    10.65    25.10   3.66    8310680.0
# LWSA3     6.54    43.11   2.03   51831100.0
# CBAV3     4.28    87.16   0.53   35498100.0
# MYPK3    14.76     9.12   6.73   21019000.0
# ...        ...      ...    ...          ...
# CRFB3    11.26     8.72   6.66  121111000.0
# YDUQ3    22.25    14.88   8.99  116395000.0
# CEAB3     6.17     7.69   5.28   26425400.0
# PTBL3     6.99    11.27   7.36   10911000.0
# SQIA3    26.65    45.90   4.04   25416100.0
#
# [197 rows x 4 columns]

# %%
tabela['ranking_ev_ebit'] = tabela['EV/EBIT'].rank(ascending = True)
tabela['ranking_roic'] = tabela['ROIC'].rank(ascending = False)
tabela['ranking_final'] = tabela['ranking_ev_ebit'] + tabela['ranking_roic']

tabela
# Out:
#        Cotação  EV/EBIT   ROIC   Liq.2meses  ranking_ev_ebit  ranking_roic  \
# Papel
# QUAL3     3.90     5.21  13.95   20118000.0             26.0          64.0
# MEGA3    10.65    25.10   3.66    8310680.0            178.0         166.0
# LWSA3     6.54    43.11   2.03   51831100.0            186.0         184.0
# CBAV3     4.28    87.16   0.53   35498100.0            192.0         194.0
# MYPK3    14.76     9.12   6.73   21019000.0             83.5         132.0
# ...        ...      ...    ...          ...              ...           ...
# CRFB3    11.26     8.72   6.66  121111000.0             81.0         133.0
# YDUQ3    22.25    14.88   8.99  116395000.0            143.0         105.0
# CEAB3     6.17     7.69   5.28   26425400.0             67.0         152.0
# PTBL3     6.99    11.27   7.36   10911000.0            111.0         129.0
# SQIA3    26.65    45.90   4.04   25416100.0            187.0         162.0
#
#        ranking_final
# Papel
# QUAL3           90.0
# ...

# %%
tabela = tabela.sort_values('ranking_final')

tabela.head(10)
# Out:
#        Cotação  EV/EBIT   ROIC    Liq.2meses  ranking_ev_ebit  ranking_roic  \
# Papel
# PSSA3    27.20     0.25  60.76  5.820690e+07              1.0           1.0
# PETR4    31.44     2.40  28.95  1.606800e+09              4.0          10.5
# PETR3    34.29     2.55  28.95  4.393320e+08              5.0          10.5
# KEPL3    10.00     4.41  43.61  1.494980e+07             14.0           2.0
# UNIP3    70.51     4.43  38.68  1.005490e+06             15.0           3.5
# WIZC3     5.99     2.23  24.18  4.427250e+06              3.0          17.0
# FESA4    43.02     4.05  25.57  9.707320e+06              8.0          15.0
# UNIP6    75.41     4.74  38.68  1.714850e+07             21.0           3.5
# CMIN3     4.05     4.56  28.49  2.938640e+07             19.0          12.0
# VLID3    16.67     4.10  20.64  6.233610e+06              9.0          23.0
#
#        ranking_final
# Papel
# PSSA3            2.0
# PETR4           14.5
# PETR3           15.5
# KEPL3           16.0
# ...
